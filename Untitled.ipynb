# %%
#import dependencies 
import pandas as pd
import numpy as np
from IPython.display import clear_output
import matplotlib.pyplot as plt
from scipy import stats

# %%
nba_seasons = "Seasons_Stats.csv"
Klay = "klay_stats.csv"
steph = "steph_stats.csv"
twenty18 = "2018.csv"
twenty19 = "2019.csv"

# %%
nba_seasons_df = pd.read_csv(nba_seasons)
klay_df = pd.read_csv(Klay)
steph_df = pd.read_csv(steph)

#encoding = "ISO-8859-1"), or alternatively encoding = "utf-8" for reading, and generally utf-8 for to_csv.


twenty_eighteen = pd.read_csv(twenty18, encoding = 'ISO-8859-1')
twenty_nineteen = pd.read_csv(twenty19, encoding = 'ISO-8859-1')

# %%
steph_df
# Out:
#       Year         Player   Age   Tm   Lg  Pos    G   GS     MP    FG  ...  \
# 0     2010  Stephen Curry  21.0  GSW  NBA   PG   80   77   2896   528  ...
# 1     2011  Stephen Curry  22.0  GSW  NBA   PG   74   74   2489   505  ...
# 2     2012  Stephen Curry  23.0  GSW  NBA   PG   26   23    732   145  ...
# 3     2013  Stephen Curry  24.0  GSW  NBA   PG   78   78   2983   626  ...
# 4     2014  Stephen Curry  25.0  GSW  NBA   PG   78   78   2846   652  ...
# 5     2015  Stephen Curry  26.0  GSW  NBA   PG   80   80   2613   653  ...
# 6     2016  Stephen Curry  27.0  GSW  NBA   PG   79   79   2700   805  ...
# 7     2017  Stephen Curry  28.0  GSW  NBA   PG   79   79   2638   675  ...
# 8     2018  Stephen Curry  29.0  GSW  NBA   PG   51   51   1631   428  ...
# 9     2019  Stephen Curry  30.0  GSW  NBA   PG   69   69   2331   632  ...
# 10  Career            NaN   NaN  NaN  NBA  NaN  694  688  23859  5649  ...
#
#       FT%  ORB   DRB   TRB   AST   STL  BLK   TOV    PF    PTS
# ...

# %%
#Drop a row by index remove career row
steph_clean = steph_df.drop([10])

# %%
steph_clean.columns
# Out:
# Index(['Year', 'Player', 'Age', 'Tm', 'Lg', 'Pos', 'G', 'GS', 'MP', 'FG',
#        'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT',
#        'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
#        'PTS'],
#       dtype='object')

# %%
steph_clean.loc[steph_clean['3P'].idxmax()]
# Out:
# Year               2016
# Player    Stephen Curry
# Age                  27
# Tm                  GSW
# Lg                  NBA
# Pos                  PG
# G                    79
# GS                   79
# MP                 2700
# FG                  805
# FGA                1598
# FG%               0.504
# 3P                  402
# 3PA                 886
# 3P%               0.454
# 2P                  403
# 2PA                 712
# 2P%               0.566
# eFG%               0.63
# FT                  363
# FTA                 400
# FT%               0.908
# ORB                  68
# DRB                 362
# TRB                 430
# AST                 527
# STL                 169
# BLK                  15
# TOV                 262
# PF                  161
# PTS                2375
# Name: 6, dtype: object

# %%
steph_min = steph_clean['3P'].min()
steph_avg = steph_clean["3P"].mean()
print(f" Stephs min 3pt season is {steph_min} and the average is {steph_avg}")
# Out:
#  Stephs min 3pt season is 55 and the average is 248.3

# %%
klay_df
# Out:
#      Year         Player   Age   Tm   Lg  Pos    G   GS     MP    FG  ...  \
# 0    2012  Klay Thompson  21.0  GSW  NBA   SG   66   29   1608   318  ...
# 1    2013  Klay Thompson  22.0  GSW  NBA   SG   82   82   2936   508  ...
# 2    2014  Klay Thompson  23.0  GSW  NBA   SG   81   81   2868   559  ...
# 3    2015  Klay Thompson  24.0  GSW  NBA   SG   77   77   2455   602  ...
# 4    2016  Klay Thompson  25.0  GSW  NBA   SG   80   80   2666   651  ...
# 5    2017  Klay Thompson  26.0  GSW  NBA   SG   78   78   2649   644  ...
# 6    2018  Klay Thompson  27.0  GSW  NBA   SG   73   73   2506   575  ...
# 7    2019  Klay Thompson  28.0  GSW  NBA   SG   78   78   2652   655  ...
# 8  Career            NaN   NaN  NaN  NBA  NaN  615  578  20340  4512  ...
#
#      FT%  ORB   DRB   TRB   AST  STL  BLK   TOV    PF    PTS
# 0  0.868   24   137   161   133   49   20   103   155    826
# 1  0.841   32   274   306   183   86   45   157   237   1359
# ...

# %%
klay_clean = klay_df.drop([8])

# %%
klay_clean.loc[klay_clean['3P'].idxmax()]
# Out:
# Year               2016
# Player    Klay Thompson
# Age                  25
# Tm                  GSW
# Lg                  NBA
# Pos                  SG
# G                    80
# GS                   80
# MP                 2666
# FG                  651
# FGA                1386
# FG%                0.47
# 3P                  276
# 3PA                 650
# 3P%               0.425
# 2P                  375
# 2PA                 736
# 2P%                0.51
# eFG%              0.569
# FT                  193
# FTA                 221
# FT%               0.873
# ORB                  35
# DRB                 271
# TRB                 306
# AST                 166
# STL                  60
# BLK                  49
# TOV                 138
# PF                  152
# PTS                1771
# Name: 4, dtype: object

# %%
klay_min = klay_clean['3P'].min()
klay_avg = klay_clean["3P"].mean()
print(f" Klays min 3pt season is {klay_min} and the average is {klay_avg}")
# Out:
#  Klays min 3pt season is 111 and the average is 224.75

# %%
nba_seasons_df
# Out:
#        Unnamed: 0    Year             Player  Pos   Age   Tm     G    GS  \
# 0               0  1950.0    Curly Armstrong  G-F  31.0  FTW  63.0   NaN
# 1               1  1950.0       Cliff Barker   SG  29.0  INO  49.0   NaN
# 2               2  1950.0      Leo Barnhorst   SF  25.0  CHS  67.0   NaN
# 3               3  1950.0         Ed Bartels    F  24.0  TOT  15.0   NaN
# 4               4  1950.0         Ed Bartels    F  24.0  DNN  13.0   NaN
# 5               5  1950.0         Ed Bartels    F  24.0  NYK   2.0   NaN
# 6               6  1950.0        Ralph Beard    G  22.0  INO  60.0   NaN
# 7               7  1950.0         Gene Berce  G-F  23.0  TRI   3.0   NaN
# 8               8  1950.0      Charlie Black  F-C  28.0  TOT  65.0   NaN
# 9               9  1950.0      Charlie Black  F-C  28.0  FTW  36.0   NaN
# 10             10  1950.0      Charlie Black  F-C  28.0  AND  29.0   NaN
# 11             11  1950.0        Nelson Bobb   PG  25.0  PHW  57.0   NaN
# ...

# %%
#remove rows for players before 1980 since no 3 pointer
df_1980 = nba_seasons_df[nba_seasons_df['Year'] >= 1980] 
df_1980.head()
# Out:
#       Unnamed: 0    Year                Player Pos   Age   Tm     G    GS  \
# 5727        5727  1980.0  Kareem Abdul-Jabbar*   C  32.0  LAL  82.0   NaN
# 5728        5728  1980.0         Tom Abernethy  PF  25.0  GSW  67.0   NaN
# 5729        5729  1980.0           Alvan Adams   C  25.0  PHO  75.0   NaN
# 5730        5730  1980.0       Tiny Archibald*  PG  31.0  BOS  80.0  80.0
# 5731        5731  1980.0         Dennis Awtrey   C  31.0  CHI  26.0   NaN
#
#           MP   PER  ...    FT%    ORB    DRB    TRB    AST    STL    BLK  \
# 5727  3143.0  25.3  ...  0.765  190.0  696.0  886.0  371.0   81.0  280.0
# 5728  1222.0  11.0  ...  0.683   62.0  129.0  191.0   87.0   35.0   12.0
# 5729  2168.0  19.2  ...  0.797  158.0  451.0  609.0  322.0  108.0   55.0
# 5730  2864.0  15.3  ...  0.830   59.0  138.0  197.0  671.0  106.0   10.0
# 5731   560.0   7.4  ...  0.640   29.0   86.0  115.0   40.0   12.0   15.0
#
#         TOV     PF     PTS
# 5727  297.0  216.0  2034.0
# ...

# %%
df_1980.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP',
#        'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%',
#        'BLK%', 'TOV%', 'USG%', 'blanl', 'OWS', 'DWS', 'WS', 'WS/48', 'blank2',
#        'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
#        '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
snipers_df= df_1980[df_1980['3P'] >= 224]

# %%
#1980-2017 snipers 

snipers_df
# Out:
#        Unnamed: 0    Year              Player Pos   Age   Tm     G    GS  \
# 12330       12330  1996.0     Mookie Blaylock  PG  28.0  ATL  81.0  81.0
# 12591       12591  1996.0      George McCloud  SF  28.0  DAL  79.0  63.0
# 12689       12689  1996.0     Mitch Richmond*  SG  30.0  SAC  81.0  81.0
# 12723       12723  1996.0        Dennis Scott  SF  27.0  ORL  82.0  82.0
# 13183       13183  1997.0      Reggie Miller*  SG  31.0  IND  81.0  81.0
# 15512       15512  2002.0           Ray Allen  SG  26.0  MIL  69.0  67.0
...
#
#        FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 240  0.839  105  523  628  318  170   34  205  214  2159
# 267  0.879   66  452  518  586  158   58  387  244  2818
# 290  0.886  106  306  412  205   58   33  146  202  1695
# 401  0.912   68  303  371  551   88   34  212  148  2067
# ...

# %%
no_steph_klay_2019 = snipers_2019_no_steph[~snipers_2019_no_steph.Player.str.contains("Klay")]
no_steph_klay_2019
# Out:
#      Year            Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 240  2019       Paul George  SF   28  OKC  77  77  2841  707  1614  ...
# 267  2019      James Harden  PG   29  HOU  78  78  2867  843  1909  ...
# 290  2019       Buddy Hield  SG   26  SAC  82  82  2615  623  1360  ...
# 401  2019    Damian Lillard  PG   28  POR  80  80  2838  681  1533  ...
# 555  2019       J.J. Redick  SG   34  PHI  76  63  2379  452  1027  ...
# 573  2019  D'Angelo Russell  PG   22  BRK  81  81  2448  659  1517  ...
# 665  2019      Kemba Walker  PG   28  CHO  82  82  2863  731  1684  ...
#
#        FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 240  0.839  105  523  628  318  170   34  205  214  2159
# 267  0.879   66  452  518  586  158   58  387  244  2818
# 290  0.886  106  306  412  205   58   33  146  202  1695
# 401  0.912   68  303  371  551   88   34  212  148  2067
# 555  0.894   20  166  186  206   32   17  101  129  1372
# ...

# %%
no_steph_klay_2019.columns
# Out:
# Index(['Year', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA',
#        'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA',
#        'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
#all none klay and steph years with above 224 3p made

#no_steph_klay_2019
#no_steph_klay_2018
#snipers2
#klay years where 3 pts are above his career average
klay_best =  klay_clean[klay_clean['3P'] >= 224] 


steph_best =  steph_clean[steph_clean['3P'] >= 224]

# %%
steph_best
#pd.merge(klay_best, steph_best, on='Player')
# Out:
#    Year         Player   Age   Tm   Lg Pos   G  GS    MP   FG  ...    FT%  \
# 3  2013  Stephen Curry  24.0  GSW  NBA  PG  78  78  2983  626  ...  0.900
# 4  2014  Stephen Curry  25.0  GSW  NBA  PG  78  78  2846  652  ...  0.885
# 5  2015  Stephen Curry  26.0  GSW  NBA  PG  80  80  2613  653  ...  0.914
# 6  2016  Stephen Curry  27.0  GSW  NBA  PG  79  79  2700  805  ...  0.908
# 7  2017  Stephen Curry  28.0  GSW  NBA  PG  79  79  2638  675  ...  0.898
# 9  2019  Stephen Curry  30.0  GSW  NBA  PG  69  69  2331  632  ...  0.916
#
#    ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 3   59  255  314  539  126   12  240  198  1786
# 4   46  288  334  666  128   14  294  194  1873
# 5   56  285  341  619  163   16  249  158  1900
# 6   68  362  430  527  169   15  262  161  2375
# 7   61  292  353  524  142   17  239  183  1999
# 9   45  324  369  361   92   25  192  166  1881
#
# [6 rows x 31 columns]

# %%
splashbros = steph_best.append(klay_best)

# %%
splashbros
# Out:
#    Year         Player   Age   Tm   Lg Pos   G  GS    MP   FG  ...    FT%  \
# 3  2013  Stephen Curry  24.0  GSW  NBA  PG  78  78  2983  626  ...  0.900
# 4  2014  Stephen Curry  25.0  GSW  NBA  PG  78  78  2846  652  ...  0.885
# 5  2015  Stephen Curry  26.0  GSW  NBA  PG  80  80  2613  653  ...  0.914
# 6  2016  Stephen Curry  27.0  GSW  NBA  PG  79  79  2700  805  ...  0.908
# 7  2017  Stephen Curry  28.0  GSW  NBA  PG  79  79  2638  675  ...  0.898
#
#    ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
# The maximum x value for our chart will be 100
x_limit = 100

# List of values from 0 to 100 each value being 1 greater than the last
x_axis = snipers2.Year.tolist()

# Create a random array of data that we will use for our y values
y_axis = snipers2["3P"].tolist()


player2 = snipers2.Player.tolist()

year2= snipers2.Year.tolist()


ax=plt.scatter(year2, y_axis, marker='o', facecolors='red', edgecolors='black')
for label, x, y in zip (player2, year2, y_axis):
   plt.annotate(label, xy= (x, y))
plt.xlabel("Years")
plt.ylabel('3P made')

plt.grid()
plt.show()

# %%
# The maximum x value for our chart will be 100
x_limit = 100

# List of values from 0 to 100 each value being 1 greater than the last
x_axis3 = no_sk_1819.Year.tolist()

# Create a random array of data that we will use for our y values
y_axis3 = no_sk_1819["3P"].tolist()


player3 = no_sk_1819.Player.tolist()

year3= no_sk_1819.Year.tolist()


ax=plt.scatter(year3, y_axis3, marker='o', facecolors='red', edgecolors='black')
for label, x, y in zip (player3, year3, y_axis3):
   plt.annotate(label, xy= (x, y))
plt.xlabel("Years")
plt.ylabel('3P made')

plt.grid()
plt.show()

# %%
year1 = splashbros.Year.tolist()
y_axis1 = splashbros["3P"].tolist()
player3 = splashbros.Player.tolist()



#year3 = 


for label, x, y in zip (player3, year1, y_axis1):
   plt.annotate(label, xy= (x, y))
plt.xlabel("Years")
plt.ylabel('3P made')
ax=plt.scatter(year1, y_axis1, marker='o', facecolors='red', edgecolors='black')

x_list = ["2013", "2016", "2018"]
y_list = [270, 270, 270]


fig = plt.figure(1, figsize=(16, 8), frameon=False, dpi=100)

plt.plot(x_list, y_list)


plt.grid()
plt.show()
fig.savefig('steph_klay.png', dpi=fig.dpi)

# %%
#no_sk_1819
#snipers2

all_but_sk = no_sk_1819.append(snipers2)
# Out:
# C:\Users\beach\Anaconda3\lib\site-packages\pandas\core\frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
all_but_sk
# Out:
#           2P    2P%    2PA     3P    3P%     3PA   3PAr    AST  AST%   Age  \
# 240    415.0  0.484  857.0  292.0  0.386   757.0    NaN  318.0   NaN  28.0
# 267    465.0  0.528  881.0  378.0  0.368  1028.0    NaN  586.0   NaN  29.0
# 290    345.0  0.487  709.0  278.0  0.427   651.0    NaN  205.0   NaN  26.0
# 401    444.0  0.499  890.0  237.0  0.369   643.0    NaN  551.0   NaN  28.0
# 555    212.0  0.502  422.0  240.0  0.397   605.0    NaN  206.0   NaN  34.0
# 573    425.0  0.482  882.0  234.0  0.369   635.0    NaN  563.0   NaN  22.0
# 665    471.0  0.494  953.0  260.0  0.356   731.0    NaN  484.0   NaN  28.0
# 176     58.0  0.479  121.0  227.0  0.392   579.0    NaN   79.0   NaN  30.0
# 209    332.0  0.454  731.0  244.0  0.401   609.0    NaN  263.0   NaN  27.0
# 232    386.0  0.531  727.0  265.0  0.367   722.0    NaN  630.0   NaN  28.0
# 369    394.0  0.501  786.0  227.0  0.361   629.0    NaN  481.0   NaN  27.0
# ...

# %%
all_but_sk.columns
# Out:
# Index(['2P', '2P%', '2PA', '3P', '3P%', '3PA', '3PAr', 'AST', 'AST%', 'Age',
#        'BLK', 'BLK%', 'BPM', 'DBPM', 'DRB', 'DRB%', 'DWS', 'FG', 'FG%', 'FGA',
#        'FT', 'FT%', 'FTA', 'FTr', 'G', 'GS', 'MP', 'OBPM', 'ORB', 'ORB%',
#        'OWS', 'PER', 'PF', 'PTS', 'Player', 'Pos', 'STL', 'STL%', 'TOV',
#        'TOV%', 'TRB', 'TRB%', 'TS%', 'Tm', 'USG%', 'Unnamed: 0', 'VORP', 'WS',
#        'WS/48', 'Year', 'blank2', 'blanl', 'eFG%'],
#       dtype='object')

# %%
df1 = pd.DataFrame(list(zip(Players_alltime, years, threes_made)), 
               columns =['Player', 'Year', 'Threes Made']) 
df1
# Out:
#                 Player    Year  Threes Made
# 0          Paul George  2019.0        292.0
# 1         James Harden  2019.0        378.0
# 2          Buddy Hield  2019.0        278.0
# 3       Damian Lillard  2019.0        237.0
# 4          J.J. Redick  2019.0        240.0
# 5     D'Angelo Russell  2019.0        234.0
# 6         Kemba Walker  2019.0        260.0
# 7      Wayne Ellington  2018.0        227.0
# 8          Paul George  2018.0        244.0
# 9         James Harden  2018.0        265.0
# 10      Damian Lillard  2018.0        227.0
# 11          Kyle Lowry  2018.0        238.0
# 12        Kemba Walker  2018.0        231.0
# 13     Mookie Blaylock  1996.0        231.0
# 14      George McCloud  1996.0        257.0
# 15     Mitch Richmond*  1996.0        225.0
# 16        Dennis Scott  1996.0        267.0
# 17      Reggie Miller*  1997.0        229.0
# 18           Ray Allen  2002.0        229.0
# 19     Peja Stojakovic  2004.0        240.0
# ...

# %%
df1['Year'] = df1['Year'].astype(str)
df1['Threes Made'] = df1['Threes Made'].astype(int)

Players_alltime =  all_but_sk.Player.tolist()
years = all_but_sk.Year.tolist()
threes_made = all_but_sk['3P'].tolist()

# %%
sk_names = splashbros.Player.tolist()
sk_years = splashbros.Year.tolist()
sk_makes = splashbros['3P'].tolist()

# %%
df11 = pd.DataFrame(list(zip(sk_names, sk_years, sk_makes)), 
               columns =['Player', 'Year', 'Threes'])

# %%
df11
# Out:
#            Player  Year  Threes
# 0   Stephen Curry  2013     272
# 1   Stephen Curry  2014     261
# 2   Stephen Curry  2015     286
# 3   Stephen Curry  2016     402
# 4   Stephen Curry  2017     324
# 5   Stephen Curry  2019     354
# 6   Klay Thompson  2015     239
# 7   Klay Thompson  2016     276
# 8   Klay Thompson  2017     268
# 9   Klay Thompson  2018     229
# 10  Klay Thompson  2019     241

# %%
final =  df11.append(df1)

# %%
final
# Out:
#                 Player  Threes  Threes Made    Year
# 0        Stephen Curry   272.0          NaN    2013
# 1        Stephen Curry   261.0          NaN    2014
# 2        Stephen Curry   286.0          NaN    2015
# 3        Stephen Curry   402.0          NaN    2016
# 4        Stephen Curry   324.0          NaN    2017
# 5        Stephen Curry   354.0          NaN    2019
# 6        Klay Thompson   239.0          NaN    2015
# 7        Klay Thompson   276.0          NaN    2016
# 8        Klay Thompson   268.0          NaN    2017
# 9        Klay Thompson   229.0          NaN    2018
# 10       Klay Thompson   241.0          NaN    2019
# 0          Paul George     NaN        292.0  2019.0
# 1         James Harden     NaN        378.0  2019.0
# 2          Buddy Hield     NaN        278.0  2019.0
# 3       Damian Lillard     NaN        237.0  2019.0
# 4          J.J. Redick     NaN        240.0  2019.0
# 5     D'Angelo Russell     NaN        234.0  2019.0
# ...

# %%
final_players = final.Player.tolist()
final_years = final.Year.tolist()
final_makes = final.Threes.tolist()

# %%
final_years.astype(str)

# %%
ax=plt.scatter(final_years, final_makes, marker='o', facecolors='red', edgecolors='black')
for label, x, y in zip (final_players, final_years, final_makes):
   plt.annotate(label, xy= (x, y))
plt.xlabel("Years")
plt.ylabel('3P made')

plt.grid()
plt.show()
